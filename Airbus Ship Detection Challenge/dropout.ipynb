# %% [markdown]
# # About
# Since I am new to learning from image segmentation and kaggle in general I want to share my noteook.
# I saw it is similar to others as it uses the U-net approach. I want to share it anyway because:
#
# - As said, the field is new to me so I am open to suggestions.
# - It visualizes some of the steps, e.g. scaling, to learn if the methods do what I expect which might be useful to others (I call them sanity checks).
# - Added stratification by the amount of salt contained in the image.
# - Added augmentation by flipping the images along the y axes (thanks to the forum for clarification).
# - Added dropout to the model which seems to improve performance.

# %%
import numpy as np
import pandas as pd

from random import randint

import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")

from sklearn.model_selection import train_test_split

from skimage.transform import resize

from keras.preprocessing.image import load_img
from keras import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.models import load_model
from keras.optimizers import Adam
from keras.utils.vis_utils import plot_model
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate, Dropout

from tqdm import tqdm_notebook


import os
import sys
import random
import warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2

from tqdm import tqdm_notebook, tnrange
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

from keras.models import Model, load_model, Sequential
from keras.layers import Input, BatchNormalization, Add, Activation,Dense, PReLU, Dropout, Flatten,concatenate, Reshape
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D,AveragePooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, LearningRateScheduler
from keras import backend as K
from keras.layers import Activation

import tensorflow as tf

from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

from keras.layers import Conv2D, MaxPooling2D, UpSampling2D
from keras.models import Model
from keras.optimizers import RMSprop, Adam

from keras.losses import binary_crossentropy

from keras.callbacks import TensorBoard
from keras.applications.vgg16 import VGG16

from sklearn.model_selection import KFold


import pydensecrf.densecrf as dcrf
from skimage.io import imread, imsave
from pydensecrf.utils import unary_from_labels, create_pairwise_bilateral
from skimage.color import gray2rgb
from skimage.color import rgb2gray
import matplotlib.pyplot as plt
import pandas as pd
from tqdm import tqdm

# %% [markdown]
# # Params and helpers

# %%
img_size_ori = 101
img_size_target = 128

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    #res = np.zeros((img_size_target, img_size_target), dtype=img.dtype)
    #res[:img_size_ori, :img_size_ori] = img
    #return res
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)
    #return img[:img_size_ori, :img_size_ori]
    


def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred = K.cast(y_pred, 'float32')
    y_pred_f = K.cast(K.greater(K.flatten(y_pred), 0.5), 'float32')
    intersection = y_true_f * y_pred_f
    score = 2. * K.sum(intersection) / (K.sum(y_true_f) + K.sum(y_pred_f))
    return score

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. - score

def dice_loss2(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return score

def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) - K.log(dice_loss2(y_true, y_pred))

def bce_logdice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) - K.log(1. - dice_loss(y_true, y_pred))

def weighted_bce_loss(y_true, y_pred, weight):
    epsilon = 1e-7
    y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
    logit_y_pred = K.log(y_pred / (1. - y_pred))
    loss = weight * (logit_y_pred * (1. - y_true) + 
                     K.log(1. + K.exp(-K.abs(logit_y_pred))) + K.maximum(-logit_y_pred, 0.))
    return K.sum(loss) / K.sum(weight)

def weighted_dice_loss(y_true, y_pred, weight):
    smooth = 1.
    w, m1, m2 = weight, y_true, y_pred
    intersection = (m1 * m2)
    score = (2. * K.sum(w * intersection) + smooth) / (K.sum(w * m1) + K.sum(w * m2) + smooth)
    loss = 1. - K.sum(score)
    return loss

def weighted_bce_dice_loss(y_true, y_pred):
    y_true = K.cast(y_true, 'float32')
    y_pred = K.cast(y_pred, 'float32')
    # if we want to get same size of output, kernel size must be odd
    averaged_mask = K.pool2d(
            y_true, pool_size=(50, 50), strides=(1, 1), padding='same', pool_mode='avg')
    weight = K.ones_like(averaged_mask)
    w0 = K.sum(weight)
    weight = 5. * K.exp(-5. * K.abs(averaged_mask - 0.5))
    w1 = K.sum(weight)
    weight *= (w0 / w1)
    loss = weighted_bce_loss(y_true, y_pred, weight) + dice_loss(y_true, y_pred)
    return loss

def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %% [markdown]
# # Loading of training/testing ids and depths
# Reading the training data and the depths, store them in a DataFrame. Also create a test DataFrame with entries from depth not in train.

# %%
train_df = pd.read_csv("/home/alexanderliao/data/Kaggle/competitions/tgs-salt-identification-challenge/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("/home/alexanderliao/data/Kaggle/competitions/tgs-salt-identification-challenge/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

# %% [markdown]
# # Read images and masks
# Load the images and masks into the DataFrame and divide the pixel values by 255.

# %%
train_df["images"] = [np.array(load_img("/home/alexanderliao/data/Kaggle/competitions/tgs-salt-identification-challenge/train/images/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
train_df["masks"] = [np.array(load_img("/home/alexanderliao/data/Kaggle/competitions/tgs-salt-identification-challenge/train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %% [markdown]
# # Calculating the salt coverage and salt coverage classes
# Counting the number of salt pixels in the masks and dividing them by the image size. Also create 11 coverage classes, -0.1 having no salt at all to 1.0 being salt only.
# Plotting the distribution of coverages and coverage classes, and the class against the raw coverage.

# %%
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)

# %%
def cov_to_class(val):    
    for i in range(0, 11):
        if val * 10 <= i :
            return i
        
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,5))
sns.distplot(train_df.coverage, kde=False, ax=axs[0])
sns.distplot(train_df.coverage_class, bins=10, kde=False, ax=axs[1])
plt.suptitle("Salt coverage")
axs[0].set_xlabel("Coverage")
axs[1].set_xlabel("Coverage class")
# Out:
# Text(0.5,0,'Coverage class')

# %%
plt.scatter(train_df.coverage, train_df.coverage_class)
plt.xlabel("Coverage")
plt.ylabel("Coverage class")
# Out:
# Text(0,0.5,'Coverage class')

# %% [markdown]
# # Plotting the depth distributions
# Separatelty plotting the depth distributions for the training and the testing data.

# %%
sns.distplot(train_df.z, label="Train")
sns.distplot(test_df.z, label="Test")
plt.legend()
plt.title("Depth distribution")
# Out:
# Text(0.5,1,'Depth distribution')

# %% [markdown]
# # Show some example images

# %%
max_images = 60
grid_width = 15
grid_height = int(max_images / grid_width)
fig, axs = plt.subplots(grid_height, grid_width, figsize=(grid_width, grid_height))
for i, idx in enumerate(train_df.index[:max_images]):
    img = train_df.loc[idx].images
    mask = train_df.loc[idx].masks
    ax = axs[int(i / grid_width), i % grid_width]
    ax.imshow(img, cmap="Greys")
    ax.imshow(mask, alpha=0.3, cmap="Greens")
    ax.text(1, img_size_ori-1, train_df.loc[idx].z, color="black")
    ax.text(img_size_ori - 1, 1, round(train_df.loc[idx].coverage, 2), color="black", ha="right", va="top")
    ax.text(1, 1, train_df.loc[idx].coverage_class, color="black", ha="left", va="top")
    ax.set_yticklabels([])
    ax.set_xticklabels([])
plt.suptitle("Green: salt. Top-left: coverage class, top-right: salt coverage, bottom-left: depth")
# Out:
# Text(0.5,0.98,'Green: salt. Top-left: coverage class, top-right: salt coverage, bottom-left: depth')

# %% [markdown]
# # Create train/validation split stratified by salt coverage
# Using the salt coverage as a stratification criterion. Also show an image to check for correct upsampling.

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test = train_test_split(
    train_df.index.values,
    np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
    np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
    train_df.coverage.values,
    train_df.z.values,
    test_size=0.2, stratify=train_df.coverage_class, random_state=1337)
# Out:
# /home/alexanderliao/anaconda3/envs/py36/lib/python3.6/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "

# %%
tmp_img = np.zeros((img_size_target, img_size_target), dtype=train_df.images.loc[ids_train[10]].dtype)
tmp_img[:img_size_ori, :img_size_ori] = train_df.images.loc[ids_train[10]]
fix, axs = plt.subplots(1, 2, figsize=(15,5))
axs[0].imshow(tmp_img, cmap="Greys")
axs[0].set_title("Original image")
axs[1].imshow(x_train[10].squeeze(), cmap="Greys")
axs[1].set_title("Scaled image")
# Out:
# Text(0.5,1,'Scaled image')

# %% [markdown]
# # Build model

# %%
def bottleneck(x, filters_bottleneck, mode='cascade', depth=6,
               kernel_size=(3, 3), activation='relu'):
    dilated_layers = []
    if mode == 'cascade':  # used in the competition
        for i in range(depth):
            x = Conv2D(filters_bottleneck, kernel_size,
                       activation=activation, padding='same', dilation_rate=2**i)(x)
            dilated_layers.append(x)
        return Add()(dilated_layers)
    elif mode == 'parallel':  # Like "Atrous Spatial Pyramid Pooling"
        for i in range(depth):
            dilated_layers.append(
                Conv2D(filters_bottleneck, kernel_size,
                       activation=activation, padding='same', dilation_rate=2**i)(x)
            )
        return Add()(dilated_layers)

def build_model(input_layer, start_neurons):
    # 128 -> 64
    conv1 = Conv2D(start_neurons * 1, (3, 3), padding="same")(input_layer)
    conv1 = BatchNormalization()(conv1)
    conv1 = Activation(activation='relu')(conv1)
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation="relu", padding="same")(conv1)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(0.25)(pool1)

    # 64 -> 32
    conv2 = Conv2D(start_neurons * 2, (3, 3), padding="same")(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Activation(activation='relu')(conv2)
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation="relu", padding="same")(conv2)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(0.5)(pool2)

    # 32 -> 16
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation="relu", padding="same")(pool2)
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation="relu", padding="same")(conv3)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(0.5)(pool3)

    # 16 -> 8
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation="relu", padding="same")(pool3)
    conv4 = Conv2D(start_neurons * 8, (3, 3), padding="same")(conv4)
    conv4 = BatchNormalization()(conv4)
    conv4 = Activation(activation='relu')(conv4)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(0.5)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), padding="same")(pool4)
    convm = BatchNormalization()(convm)
    convm = Activation(activation='relu')(convm)
    convm = Conv2D(start_neurons * 16, (3, 3), activation="relu", padding="same")(convm)

    # 8 -> 16
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(0.5)(uconv4)
    uconv4 = Conv2D(start_neurons * 8, (3, 3), padding="same")(uconv4)
    uconv4 = BatchNormalization()(uconv4)
    uconv4 = Activation(activation='relu')(uconv4)
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation="relu", padding="same")(uconv4)

    # 16 -> 32
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    uconv3 = concatenate([deconv3, conv3])
    uconv3 = Dropout(0.5)(uconv3)
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation="relu", padding="same")(uconv3)
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation="relu", padding="same")(uconv3)

    # 32 -> 64
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
    uconv2 = Dropout(0.5)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), padding="same")(uconv2)
    uconv2 = BatchNormalization()(uconv2)
    uconv2 = Activation(activation='relu')(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation="relu", padding="same")(uconv2)

    # 64 -> 128
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    uconv1 = Dropout(0.5)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation="relu", padding="same")(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation="relu", padding="same")(uconv1)

    uncov1 = Dropout(0.5)(uconv1)
    output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    
    return output_layer

input_layer = Input((img_size_target, img_size_target, 1))
output_layer = build_model(input_layer, 16)

# %%
model = Model(input_layer, output_layer)

# %%
model.compile(loss=bce_dice_loss, optimizer="adam", metrics=[mean_iou,dice_coef,"accuracy"])

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 128, 128, 1)  0
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 128, 128, 16) 160         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 16) 2320        conv2d_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 16)   0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 64, 64, 16)   0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 32)   4640        dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 32)   128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 64, 32)   9248        activation_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 32)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 32, 32, 32)   0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 64)   18496       dropout_11[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 64)   36928       conv2d_24[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 64)   0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 16, 16, 64)   0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 16, 16, 128)  73856       dropout_12[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 128)  512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 8, 8, 128)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 8, 8, 128)    0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 8, 256)    295168      dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 256)    1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 8, 8, 256)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 8, 8, 256)    590080      activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 16, 16, 128)  295040      conv2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 16, 16, 256)  0           conv2d_transpose_5[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 16, 16, 256)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 16, 128)  295040      dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 128)  512         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 16, 16, 128)  147584      activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 32, 32, 64)   73792       conv2d_31[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 32, 32, 128)  0           conv2d_transpose_6[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 32, 32, 128)  0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 32, 32, 64)   73792       dropout_15[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 32, 32, 64)   36928       conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 64, 64, 32)   18464       conv2d_33[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 64, 64, 64)   0           conv2d_transpose_7[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 64, 64, 64)   0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 64, 64, 32)   18464       dropout_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 32)   128         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 64, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 64, 64, 32)   9248        activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 128, 128, 16) 4624        conv2d_35[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 128, 128, 32) 0           conv2d_transpose_8[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 128, 128, 32) 0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 128, 128, 16) 4624        dropout_17[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 128, 128, 16) 2320        conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 128, 128, 1)  17          conv2d_37[0][0]
# ==================================================================================================
# Total params: 2,160,721
# Trainable params: 2,159,569
# Non-trainable params: 1,152
# __________________________________________________________________________________________________

# %% [markdown]
# # Data augmentation

# %%
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)

# %%
fig, axs = plt.subplots(2, 10, figsize=(15,3))
for i in range(10):
    axs[0][i].imshow(x_train[i].squeeze(), cmap="Greys")
    axs[0][i].imshow(y_train[i].squeeze(), cmap="Greens", alpha=0.3)
    axs[1][i].imshow(x_train[int(len(x_train)/2 + i)].squeeze(), cmap="Greys")
    axs[1][i].imshow(y_train[int(len(y_train)/2 + i)].squeeze(), cmap="Greens", alpha=0.3)
fig.suptitle("Top row: original images, bottom row: augmented images")
# Out:
# Text(0.5,0.98,'Top row: original images, bottom row: augmented images')

# %% [markdown]
# # Training

# %%
early_stopping = EarlyStopping(patience=50, verbose=1)
model_checkpoint = ModelCheckpoint("./keras.model", save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1)

epochs = 200
batch_size = 64

callbacks = [    early_stopping,
                 model_checkpoint,
                 reduce_lr,
            TensorBoard(log_dir='./graph', histogram_freq=0, write_graph=True, write_images=True)]

gen = ImageDataGenerator(vertical_flip = True,
                         width_shift_range = 0.1,
                         height_shift_range = 0.1,
                         zoom_range = 0.1,

                        )
valid_gen = ImageDataGenerator(
                         vertical_flip = True,
                         width_shift_range = 0.1,
                         height_shift_range = 0.1,
                         zoom_range = 0.1,
                        )

"""
history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=callbacks)
"""


history = model.fit_generator(gen.flow(x_train, y_train,batch_size=batch_size),
                    validation_data=valid_gen.flow(x_valid,y_valid,batch_size=batch_size), 
                    epochs=epochs,
                    steps_per_epoch=80,          
                    callbacks=callbacks)
# Out:
# Epoch 1/200
# 80/80 [==============================] - 66s 822ms/step - loss: 0.9833 - mean_iou: 0.5402 - dice_coef: 0.6450 - acc: 0.8163 - val_loss: 6.5868 - val_mean_iou: 0.5438 - val_dice_coef: 0.4258 - val_acc: 0.3316
#
# Epoch 00001: val_loss improved from inf to 6.58683, saving model to ./keras.model
# Epoch 2/200
# 80/80 [==============================] - 64s 798ms/step - loss: 0.9599 - mean_iou: 0.5441 - dice_coef: 0.6502 - acc: 0.8240 - val_loss: 2.2524 - val_mean_iou: 0.5518 - val_dice_coef: 0.5165 - val_acc: 0.5612
#
# Epoch 00002: val_loss improved from 6.58683 to 2.25235, saving model to ./keras.model
# Epoch 3/200
# 80/80 [==============================] - 65s 811ms/step - loss: 0.9541 - mean_iou: 0.5556 - dice_coef: 0.6546 - acc: 0.8195 - val_loss: 1.3925 - val_mean_iou: 0.5608 - val_dice_coef: 0.5678 - val_acc: 0.6604
#
# Epoch 00003: val_loss improved from 2.25235 to 1.39253, saving model to ./keras.model
# Epoch 4/200
# 80/80 [==============================] - 64s 802ms/step - loss: 0.8820 - mean_iou: 0.5662 - dice_coef: 0.6759 - acc: 0.8393 - val_loss: 1.8844 - val_mean_iou: 0.5710 - val_dice_coef: 0.5341 - val_acc: 0.5995
#
# Epoch 00004: val_loss did not improve from 1.39253
# Epoch 5/200
# 80/80 [==============================] - 64s 802ms/step - loss: 0.8754 - mean_iou: 0.5751 - dice_coef: 0.6797 - acc: 0.8407 - val_loss: 1.1078 - val_mean_iou: 0.5798 - val_dice_coef: 0.6532 - val_acc: 0.7800
#
# Epoch 00005: val_loss improved from 1.39253 to 1.10779, saving model to ./keras.model
# Epoch 6/200
# 80/80 [==============================] - 64s 803ms/step - loss: 0.8240 - mean_iou: 0.5851 - dice_coef: 0.6987 - acc: 0.8486 - val_loss: 0.9864 - val_mean_iou: 0.5891 - val_dice_coef: 0.6706 - val_acc: 0.8051
#
# Epoch 00006: val_loss improved from 1.10779 to 0.98637, saving model to ./keras.model
# Epoch 7/200
# 80/80 [==============================] - 64s 803ms/step - loss: 0.7874 - mean_iou: 0.5935 - dice_coef: 0.7134 - acc: 0.8528 - val_loss: 1.2321 - val_mean_iou: 0.5978 - val_dice_coef: 0.6494 - val_acc: 0.7661
#
# Epoch 00007: val_loss did not improve from 0.98637
# Epoch 8/200
# 80/80 [==============================] - 64s 806ms/step - loss: 0.8059 - mean_iou: 0.6008 - dice_coef: 0.7029 - acc: 0.8532 - val_loss: 1.1544 - val_mean_iou: 0.6040 - val_dice_coef: 0.6525 - val_acc: 0.7733
#
# Epoch 00008: val_loss did not improve from 0.98637
# Epoch 9/200
# 80/80 [==============================] - 64s 804ms/step - loss: 0.7454 - mean_iou: 0.6072 - dice_coef: 0.7275 - acc: 0.8624 - val_loss: 1.1589 - val_mean_iou: 0.6105 - val_dice_coef: 0.6407 - val_acc: 0.7631
#
# Epoch 00009: val_loss did not improve from 0.98637
# Epoch 10/200
# 80/80 [==============================] - 64s 803ms/step - loss: 0.7303 - mean_iou: 0.6132 - dice_coef: 0.7303 - acc: 0.8657 - val_loss: 1.2676 - val_mean_iou: 0.6158 - val_dice_coef: 0.6054 - val_acc: 0.7020
#
# Epoch 00010: val_loss did not improve from 0.98637
# Epoch 11/200
# 80/80 [==============================] - 64s 802ms/step - loss: 0.7206 - mean_iou: 0.6180 - dice_coef: 0.7334 - acc: 0.8622 - val_loss: 0.9245 - val_mean_iou: 0.6206 - val_dice_coef: 0.6885 - val_acc: 0.8054
#
# Epoch 00011: val_loss improved from 0.98637 to 0.92451, saving model to ./keras.model
# Epoch 12/200
# 80/80 [==============================] - 64s 802ms/step - loss: 0.7425 - mean_iou: 0.6229 - dice_coef: 0.7246 - acc: 0.8628 - val_loss: 1.1395 - val_mean_iou: 0.6248 - val_dice_coef: 0.6402 - val_acc: 0.7537
#
# Epoch 00012: val_loss did not improve from 0.92451
# Epoch 13/200
# 80/80 [==============================] - 64s 804ms/step - loss: 0.6629 - mean_iou: 0.6271 - dice_coef: 0.7525 - acc: 0.8745 - val_loss: 1.1510 - val_mean_iou: 0.6295 - val_dice_coef: 0.6476 - val_acc: 0.7647
#
# Epoch 00013: val_loss did not improve from 0.92451
# Epoch 14/200
# 80/80 [==============================] - 64s 801ms/step - loss: 0.7144 - mean_iou: 0.6311 - dice_coef: 0.7352 - acc: 0.8650 - val_loss: 0.9510 - val_mean_iou: 0.6328 - val_dice_coef: 0.6799 - val_acc: 0.8039
#
# Epoch 00014: val_loss did not improve from 0.92451
# Epoch 15/200
# 80/80 [==============================] - 64s 801ms/step - loss: 0.6718 - mean_iou: 0.6347 - dice_coef: 0.7522 - acc: 0.8730 - val_loss: 0.8250 - val_mean_iou: 0.6368 - val_dice_coef: 0.7308 - val_acc: 0.8585
#
# Epoch 00015: val_loss improved from 0.92451 to 0.82498, saving model to ./keras.model
# Epoch 16/200
# 80/80 [==============================] - 64s 804ms/step - loss: 0.6497 - mean_iou: 0.6387 - dice_coef: 0.7551 - acc: 0.8773 - val_loss: 0.7754 - val_mean_iou: 0.6407 - val_dice_coef: 0.7235 - val_acc: 0.8479
#
# Epoch 00016: val_loss improved from 0.82498 to 0.77542, saving model to ./keras.model
# Epoch 17/200
# 80/80 [==============================] - 70s 873ms/step - loss: 0.6178 - mean_iou: 0.6428 - dice_coef: 0.7719 - acc: 0.8823 - val_loss: 0.7373 - val_mean_iou: 0.6448 - val_dice_coef: 0.7310 - val_acc: 0.8453
#
# Epoch 00017: val_loss improved from 0.77542 to 0.73730, saving model to ./keras.model
# Epoch 18/200
# 80/80 [==============================] - 68s 855ms/step - loss: 0.6268 - mean_iou: 0.6466 - dice_coef: 0.7681 - acc: 0.8805 - val_loss: 0.7524 - val_mean_iou: 0.6485 - val_dice_coef: 0.7511 - val_acc: 0.8641
#
# Epoch 00018: val_loss did not improve from 0.73730
# Epoch 19/200
# 80/80 [==============================] - 69s 864ms/step - loss: 0.6250 - mean_iou: 0.6502 - dice_coef: 0.7682 - acc: 0.8815 - val_loss: 0.8140 - val_mean_iou: 0.6518 - val_dice_coef: 0.7261 - val_acc: 0.8352
#
# Epoch 00019: val_loss did not improve from 0.73730
# Epoch 20/200
# 80/80 [==============================] - 71s 889ms/step - loss: 0.6059 - mean_iou: 0.6536 - dice_coef: 0.7751 - acc: 0.8845 - val_loss: 1.4463 - val_mean_iou: 0.6547 - val_dice_coef: 0.6001 - val_acc: 0.6827
#
# Epoch 00020: val_loss did not improve from 0.73730
# Epoch 21/200
# 80/80 [==============================] - 69s 857ms/step - loss: 0.6177 - mean_iou: 0.6556 - dice_coef: 0.7728 - acc: 0.8810 - val_loss: 0.6919 - val_mean_iou: 0.6571 - val_dice_coef: 0.7591 - val_acc: 0.8664
#
# Epoch 00021: val_loss improved from 0.73730 to 0.69194, saving model to ./keras.model
# Epoch 22/200
# 80/80 [==============================] - 68s 851ms/step - loss: 0.5830 - mean_iou: 0.6586 - dice_coef: 0.7836 - acc: 0.8885 - val_loss: 0.6859 - val_mean_iou: 0.6602 - val_dice_coef: 0.7493 - val_acc: 0.8676
#
# Epoch 00022: val_loss improved from 0.69194 to 0.68592, saving model to ./keras.model
# Epoch 23/200
# 80/80 [==============================] - 70s 869ms/step - loss: 0.5984 - mean_iou: 0.6616 - dice_coef: 0.7796 - acc: 0.8870 - val_loss: 0.6662 - val_mean_iou: 0.6629 - val_dice_coef: 0.7613 - val_acc: 0.8737
#
# Epoch 00023: val_loss improved from 0.68592 to 0.66623, saving model to ./keras.model
# Epoch 24/200
# 80/80 [==============================] - 69s 864ms/step - loss: 0.5892 - mean_iou: 0.6642 - dice_coef: 0.7825 - acc: 0.8873 - val_loss: 0.9866 - val_mean_iou: 0.6653 - val_dice_coef: 0.6520 - val_acc: 0.8239
#
# Epoch 00024: val_loss did not improve from 0.66623
# Epoch 25/200
# 80/80 [==============================] - 69s 861ms/step - loss: 0.5858 - mean_iou: 0.6664 - dice_coef: 0.7834 - acc: 0.8881 - val_loss: 0.6996 - val_mean_iou: 0.6675 - val_dice_coef: 0.7515 - val_acc: 0.8668
#
# Epoch 00025: val_loss did not improve from 0.66623
# Epoch 26/200
# 80/80 [==============================] - 69s 861ms/step - loss: 0.5697 - mean_iou: 0.6687 - dice_coef: 0.7891 - acc: 0.8905 - val_loss: 0.6688 - val_mean_iou: 0.6699 - val_dice_coef: 0.7613 - val_acc: 0.8717
#
# Epoch 00026: val_loss did not improve from 0.66623
# Epoch 27/200
# 80/80 [==============================] - 71s 882ms/step - loss: 0.5807 - mean_iou: 0.6710 - dice_coef: 0.7830 - acc: 0.8876 - val_loss: 0.9077 - val_mean_iou: 0.6720 - val_dice_coef: 0.7056 - val_acc: 0.8545
#
# Epoch 00027: val_loss did not improve from 0.66623
# Epoch 28/200
# 80/80 [==============================] - 68s 851ms/step - loss: 0.5921 - mean_iou: 0.6728 - dice_coef: 0.7804 - acc: 0.8872 - val_loss: 0.9538 - val_mean_iou: 0.6737 - val_dice_coef: 0.6848 - val_acc: 0.7924
#
# Epoch 00028: val_loss did not improve from 0.66623
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 29/200
# 80/80 [==============================] - 67s 840ms/step - loss: 0.5606 - mean_iou: 0.6747 - dice_coef: 0.7914 - acc: 0.8924 - val_loss: 0.6541 - val_mean_iou: 0.6759 - val_dice_coef: 0.7716 - val_acc: 0.8706
#
# Epoch 00029: val_loss improved from 0.66623 to 0.65410, saving model to ./keras.model
# Epoch 30/200
# 80/80 [==============================] - 72s 904ms/step - loss: 0.5166 - mean_iou: 0.6770 - dice_coef: 0.8076 - acc: 0.8977 - val_loss: 0.6363 - val_mean_iou: 0.6783 - val_dice_coef: 0.7663 - val_acc: 0.8682
#
# Epoch 00030: val_loss improved from 0.65410 to 0.63633, saving model to ./keras.model
# Epoch 31/200
# 80/80 [==============================] - 67s 841ms/step - loss: 0.5176 - mean_iou: 0.6794 - dice_coef: 0.8066 - acc: 0.8999 - val_loss: 0.6440 - val_mean_iou: 0.6806 - val_dice_coef: 0.7709 - val_acc: 0.8713
#
# Epoch 00031: val_loss did not improve from 0.63633
# Epoch 32/200
# 80/80 [==============================] - 67s 832ms/step - loss: 0.5074 - mean_iou: 0.6818 - dice_coef: 0.8115 - acc: 0.9006 - val_loss: 0.6286 - val_mean_iou: 0.6829 - val_dice_coef: 0.7784 - val_acc: 0.8765
#
# Epoch 00032: val_loss improved from 0.63633 to 0.62860, saving model to ./keras.model
# Epoch 33/200
# 80/80 [==============================] - 66s 824ms/step - loss: 0.4927 - mean_iou: 0.6841 - dice_coef: 0.8177 - acc: 0.9030 - val_loss: 0.7169 - val_mean_iou: 0.6852 - val_dice_coef: 0.7356 - val_acc: 0.8418
#
# Epoch 00033: val_loss did not improve from 0.62860
# Epoch 34/200
# 80/80 [==============================] - 68s 845ms/step - loss: 0.5139 - mean_iou: 0.6861 - dice_coef: 0.8063 - acc: 0.8995 - val_loss: 0.6515 - val_mean_iou: 0.6871 - val_dice_coef: 0.7699 - val_acc: 0.8696
#
# Epoch 00034: val_loss did not improve from 0.62860
# Epoch 35/200
# 80/80 [==============================] - 69s 857ms/step - loss: 0.5181 - mean_iou: 0.6881 - dice_coef: 0.8062 - acc: 0.9006 - val_loss: 0.6808 - val_mean_iou: 0.6890 - val_dice_coef: 0.7555 - val_acc: 0.8580
#
# Epoch 00035: val_loss did not improve from 0.62860
# Epoch 36/200
# 80/80 [==============================] - 67s 843ms/step - loss: 0.5082 - mean_iou: 0.6899 - dice_coef: 0.8088 - acc: 0.9019 - val_loss: 0.6857 - val_mean_iou: 0.6908 - val_dice_coef: 0.7552 - val_acc: 0.8577
#
# Epoch 00036: val_loss did not improve from 0.62860
# Epoch 37/200
# 80/80 [==============================] - 77s 966ms/step - loss: 0.5029 - mean_iou: 0.6917 - dice_coef: 0.8136 - acc: 0.9010 - val_loss: 0.7109 - val_mean_iou: 0.6926 - val_dice_coef: 0.7419 - val_acc: 0.8515
#
# Epoch 00037: val_loss did not improve from 0.62860
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 38/200
# 80/80 [==============================] - 65s 807ms/step - loss: 0.5131 - mean_iou: 0.6933 - dice_coef: 0.8075 - acc: 0.8995 - val_loss: 0.6914 - val_mean_iou: 0.6941 - val_dice_coef: 0.7458 - val_acc: 0.8515
#
# Epoch 00038: val_loss did not improve from 0.62860
# Epoch 39/200
# 80/80 [==============================] - 68s 849ms/step - loss: 0.4894 - mean_iou: 0.6949 - dice_coef: 0.8148 - acc: 0.9039 - val_loss: 0.6659 - val_mean_iou: 0.6957 - val_dice_coef: 0.7568 - val_acc: 0.8602
#
# Epoch 00039: val_loss did not improve from 0.62860
# Epoch 40/200
# 80/80 [==============================] - 70s 870ms/step - loss: 0.4847 - mean_iou: 0.6965 - dice_coef: 0.8181 - acc: 0.9042 - val_loss: 0.6631 - val_mean_iou: 0.6973 - val_dice_coef: 0.7556 - val_acc: 0.8599
#
# Epoch 00040: val_loss did not improve from 0.62860
# Epoch 41/200
# 80/80 [==============================] - 69s 863ms/step - loss: 0.4954 - mean_iou: 0.6980 - dice_coef: 0.8126 - acc: 0.9026 - val_loss: 0.6677 - val_mean_iou: 0.6988 - val_dice_coef: 0.7551 - val_acc: 0.8586
#
# Epoch 00041: val_loss did not improve from 0.62860
# Epoch 42/200
# 80/80 [==============================] - 67s 843ms/step - loss: 0.4987 - mean_iou: 0.6995 - dice_coef: 0.8140 - acc: 0.9016 - val_loss: 0.6546 - val_mean_iou: 0.7002 - val_dice_coef: 0.7598 - val_acc: 0.8617
#
# Epoch 00042: val_loss did not improve from 0.62860
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 43/200
# 80/80 [==============================] - 69s 864ms/step - loss: 0.4857 - mean_iou: 0.7010 - dice_coef: 0.8175 - acc: 0.9054 - val_loss: 0.6550 - val_mean_iou: 0.7017 - val_dice_coef: 0.7626 - val_acc: 0.8651
#
# Epoch 00043: val_loss did not improve from 0.62860
# Epoch 44/200
# 80/80 [==============================] - 69s 867ms/step - loss: 0.4809 - mean_iou: 0.7024 - dice_coef: 0.8183 - acc: 0.9047 - val_loss: 0.6755 - val_mean_iou: 0.7031 - val_dice_coef: 0.7524 - val_acc: 0.8566
#
# Epoch 00044: val_loss did not improve from 0.62860
# Epoch 45/200
# 80/80 [==============================] - 69s 859ms/step - loss: 0.4970 - mean_iou: 0.7037 - dice_coef: 0.8140 - acc: 0.9023 - val_loss: 0.6869 - val_mean_iou: 0.7043 - val_dice_coef: 0.7487 - val_acc: 0.8542
#
# Epoch 00045: val_loss did not improve from 0.62860
# Epoch 46/200
# 80/80 [==============================] - 71s 890ms/step - loss: 0.4987 - mean_iou: 0.7049 - dice_coef: 0.8139 - acc: 0.9013 - val_loss: 0.6984 - val_mean_iou: 0.7055 - val_dice_coef: 0.7437 - val_acc: 0.8515
#
# Epoch 00046: val_loss did not improve from 0.62860
# Epoch 47/200
# 80/80 [==============================] - 71s 882ms/step - loss: 0.4788 - mean_iou: 0.7061 - dice_coef: 0.8198 - acc: 0.9061 - val_loss: 0.6880 - val_mean_iou: 0.7067 - val_dice_coef: 0.7461 - val_acc: 0.8512
#
# Epoch 00047: val_loss did not improve from 0.62860
# Epoch 48/200
# 80/80 [==============================] - 71s 890ms/step - loss: 0.5010 - mean_iou: 0.7072 - dice_coef: 0.8124 - acc: 0.9015 - val_loss: 0.6896 - val_mean_iou: 0.7078 - val_dice_coef: 0.7503 - val_acc: 0.8536
#
# Epoch 00048: val_loss did not improve from 0.62860
# Epoch 49/200
# 80/80 [==============================] - 69s 863ms/step - loss: 0.4801 - mean_iou: 0.7083 - dice_coef: 0.8206 - acc: 0.9068 - val_loss: 0.6818 - val_mean_iou: 0.7089 - val_dice_coef: 0.7504 - val_acc: 0.8578
#
# Epoch 00049: val_loss did not improve from 0.62860
# Epoch 50/200
# 80/80 [==============================] - 74s 926ms/step - loss: 0.4874 - mean_iou: 0.7095 - dice_coef: 0.8188 - acc: 0.9038 - val_loss: 0.6670 - val_mean_iou: 0.7100 - val_dice_coef: 0.7548 - val_acc: 0.8556
#
# Epoch 00050: val_loss did not improve from 0.62860
# Epoch 51/200
# 80/80 [==============================] - 74s 930ms/step - loss: 0.4844 - mean_iou: 0.7105 - dice_coef: 0.8195 - acc: 0.9034 - val_loss: 0.6678 - val_mean_iou: 0.7111 - val_dice_coef: 0.7543 - val_acc: 0.8608
#
# Epoch 00051: val_loss did not improve from 0.62860
# Epoch 52/200
# 80/80 [==============================] - 71s 892ms/step - loss: 0.4835 - mean_iou: 0.7116 - dice_coef: 0.8185 - acc: 0.9050 - val_loss: 0.6409 - val_mean_iou: 0.7121 - val_dice_coef: 0.7673 - val_acc: 0.8682
#
# Epoch 00052: val_loss did not improve from 0.62860
# Epoch 53/200
# 80/80 [==============================] - 72s 902ms/step - loss: 0.4934 - mean_iou: 0.7126 - dice_coef: 0.8138 - acc: 0.9024 - val_loss: 0.6497 - val_mean_iou: 0.7130 - val_dice_coef: 0.7655 - val_acc: 0.8639
#
# Epoch 00053: val_loss did not improve from 0.62860
# Epoch 54/200
# 80/80 [==============================] - 74s 921ms/step - loss: 0.4897 - mean_iou: 0.7135 - dice_coef: 0.8161 - acc: 0.9040 - val_loss: 0.6511 - val_mean_iou: 0.7140 - val_dice_coef: 0.7633 - val_acc: 0.8655
#
# Epoch 00054: val_loss did not improve from 0.62860
# Epoch 55/200
# 80/80 [==============================] - 75s 931ms/step - loss: 0.4898 - mean_iou: 0.7144 - dice_coef: 0.8156 - acc: 0.9035 - val_loss: 0.6421 - val_mean_iou: 0.7149 - val_dice_coef: 0.7737 - val_acc: 0.8689
#
# Epoch 00055: val_loss did not improve from 0.62860
# Epoch 56/200
# 80/80 [==============================] - 72s 905ms/step - loss: 0.4862 - mean_iou: 0.7154 - dice_coef: 0.8188 - acc: 0.9042 - val_loss: 0.6624 - val_mean_iou: 0.7158 - val_dice_coef: 0.7609 - val_acc: 0.8629
#
# Epoch 00056: val_loss did not improve from 0.62860
# Epoch 57/200
# 80/80 [==============================] - 75s 937ms/step - loss: 0.4873 - mean_iou: 0.7162 - dice_coef: 0.8165 - acc: 0.9049 - val_loss: 0.6474 - val_mean_iou: 0.7166 - val_dice_coef: 0.7659 - val_acc: 0.8667
#
# Epoch 00057: val_loss did not improve from 0.62860
# Epoch 00057: early stopping

# %%
fig, (ax_loss, ax_acc) = plt.subplots(1, 2, figsize=(15,5))
ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
ax_acc.plot(history.epoch, history.history["acc"], label="Train accuracy")
ax_acc.plot(history.epoch, history.history["val_acc"], label="Validation accuracy")

# %%
model.load_weights("./keras.model")

# %% [markdown]
# # Predict the validation set to do a sanity check
# Again plot some sample images including the predictions.

# %%
preds_valid = model.predict(x_valid).reshape(-1, img_size_target, img_size_target)
preds_valid = np.array([downsample(x) for x in preds_valid])
y_valid = np.array([downsample(x) for x in y_valid])
# Out:
# /home/alexanderliao/anaconda3/envs/py36/lib/python3.6/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "

# %%
max_images = 60
grid_width = 15
grid_height = int(max_images / grid_width)
fig, axs = plt.subplots(grid_height, grid_width, figsize=(grid_width, grid_height))
for i, idx in enumerate(ids_train[:max_images]):
    img = train_df.loc[idx].images
    mask = train_df.loc[idx].masks
    pred = preds_valid[i]
    ax = axs[int(i / grid_width), i % grid_width]
    ax.imshow(img, cmap="Greys")
    ax.imshow(mask, alpha=0.3, cmap="Greens")
    ax.imshow(pred, alpha=0.3, cmap="OrRd")
    ax.text(1, img_size_ori-1, train_df.loc[idx].z, color="black")
    ax.text(img_size_ori - 1, 1, round(train_df.loc[idx].coverage, 2), color="black", ha="right", va="top")
    ax.text(1, 1, train_df.loc[idx].coverage_class, color="black", ha="left", va="top")
    ax.set_yticklabels([])
    ax.set_xticklabels([])
plt.suptitle("Green: salt, Red: prediction. Top-left: coverage class, top-right: salt coverage, bottom-left: depth")
# Out:
# Text(0.5,0.98,'Green: salt, Red: prediction. Top-left: coverage class, top-right: salt coverage, bottom-left: depth')

# %% [markdown]
# # Scoring
# Score the model and do a threshold optimization by the best IoU.

# %%
# src: https://www.kaggle.com/aglotero/another-iou-metric
def iou_metric(y_true_in, y_pred_in, print_table=False):
    labels = y_true_in
    y_pred = y_pred_in
    
    true_objects = 2
    pred_objects = 2

    intersection = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=(true_objects, pred_objects))[0]

    # Compute areas (needed for finding the union between all objects)
    area_true = np.histogram(labels, bins = true_objects)[0]
    area_pred = np.histogram(y_pred, bins = pred_objects)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    # Compute union
    union = area_true + area_pred - intersection

    # Exclude background from the analysis
    intersection = intersection[1:,1:]
    union = union[1:,1:]
    union[union == 0] = 1e-9

    # Compute the intersection over union
    iou = intersection / union

    # Precision helper function
    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    # Loop over IoU thresholds
    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
    
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    metric = []
    for batch in range(batch_size):
        value = iou_metric(y_true_in[batch], y_pred_in[batch])
        metric.append(value)
    return np.mean(metric)

# %%
thresholds = np.linspace(0, 1, 50)
ious = np.array([iou_metric_batch(y_valid, np.int32(preds_valid > threshold)) for threshold in tqdm_notebook(thresholds)])
# Out:
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))

# %%
threshold_best_index = np.argmax(ious[9:-10]) + 9
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

# %%
plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()

# %% [markdown]
# # Another sanity check with adjusted threshold
# Again some sample images with the adjusted threshold.

# %%
max_images = 60
grid_width = 15
grid_height = int(max_images / grid_width)
fig, axs = plt.subplots(grid_height, grid_width, figsize=(grid_width, grid_height))
for i, idx in enumerate(ids_train[:max_images]):
    img = train_df.loc[idx].images
    mask = train_df.loc[idx].masks
    pred = preds_valid[i]
    ax = axs[int(i / grid_width), i % grid_width]
    ax.imshow(img, cmap="Greys")
    ax.imshow(mask, alpha=0.3, cmap="Greens")
    ax.imshow(np.array(np.round(pred > threshold_best), dtype=np.float32), alpha=0.3, cmap="OrRd")
    ax.text(1, img_size_ori-1, train_df.loc[idx].z, color="black")
    ax.text(img_size_ori - 1, 1, round(train_df.loc[idx].coverage, 2), color="black", ha="right", va="top")
    ax.text(1, 1, train_df.loc[idx].coverage_class, color="black", ha="left", va="top")
    ax.set_yticklabels([])
    ax.set_xticklabels([])
plt.suptitle("Green: salt, Red: prediction. Top-left: coverage class, top-right: salt coverage, bottom-left: depth")
# Out:
# Text(0.5,0.98,'Green: salt, Red: prediction. Top-left: coverage class, top-right: salt coverage, bottom-left: depth')

# %% [markdown]
# # Submission
# Load, predict and submit the test image predictions.

# %%
# Source https://www.kaggle.com/bguberfain/unet-with-depth
def RLenc(img, order='F', format=True):
    """
    img is binary mask image, shape (r,c)
    order is down-then-right, i.e. Fortran
    format determines if the order needs to be preformatted (according to submission rules) or not

    returns run length as an array or string (if format is True)
    """
    bytes = img.reshape(img.shape[0] * img.shape[1], order=order)
    runs = []  ## list of run lengths
    r = 0  ## the current run length
    pos = 1  ## count starts from 1 per WK
    for c in bytes:
        if (c == 0):
            if r != 0:
                runs.append((pos, r))
                pos += r
                r = 0
            pos += 1
        else:
            r += 1

    # if last run is unsaved (i.e. data ends with 1)
    if r != 0:
        runs.append((pos, r))
        pos += r
        r = 0

    if format:
        z = ''

        for rr in runs:
            z += '{} {} '.format(rr[0], rr[1])
        return z[:-1]
    else:
        return runs

# %%
x_test = np.array([upsample(np.array(load_img("/home/alexanderliao/data/Kaggle/competitions/tgs-salt-identification-challenge/test/images/{}.png".format(idx), grayscale=True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target, 1)
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))
# /home/alexanderliao/anaconda3/envs/py36/lib/python3.6/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "

# %%
preds_test = model.predict(x_test)

# %%
pred_dict = {idx: RLenc(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))
# /home/alexanderliao/anaconda3/envs/py36/lib/python3.6/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "

# %%
sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub.to_csv('submission.csv')

# %%
def rle_decode(rle_mask):
    '''
    rle_mask: run-length as string formated (start length)
    shape: (height,width) of array to return 
    Returns numpy array, 1 - mask, 0 - background

    '''
    s = rle_mask.split()
    starts, lengths = [np.asarray(x, dtype=int) for x in (s[0:][::2], s[1:][::2])]
    starts -= 1
    ends = starts + lengths
    img = np.zeros(101*101, dtype=np.uint8)
    for lo, hi in zip(starts, ends):
        img[lo:hi] = 1
    return img.reshape(101,101)

# %%
"""
reading and decoding the submission 

"""
print(os.getcwd())
df = pd.read_csv('./submission.csv')
i = 0
j = 0
plt.figure(figsize=(30,15))
plt.subplots_adjust(bottom=0.2, top=0.8, hspace=0.2)  #adjust this to change vertical and horiz. spacings..
# Visualizing the predicted outputs
while True:
    if str(df.loc[i,'rle_mask'])!=str(np.nan):        
        decoded_mask = rle_decode(df.loc[i,'rle_mask'])
        plt.subplot(1,6,j+1)
        plt.imshow(decoded_mask)
        plt.title('ID: '+df.loc[i,'id'])
        j = j + 1
        if j>5:
            break
    i = i + 1

# %%
"""
Function which returns the labelled image after applying CRF

"""
#Original_image = Image which has to labelled
#Mask image = Which has been labelled by some technique..
def crf(original_image, mask_img):
    
    # Converting annotated image to RGB if it is Gray scale
    if(len(mask_img.shape)<3):
        mask_img = gray2rgb(mask_img)

#     #Converting the annotations RGB color to single 32 bit integer
    annotated_label = mask_img[:,:,0] + (mask_img[:,:,1]<<8) + (mask_img[:,:,2]<<16)
    
#     # Convert the 32bit integer color to 0,1, 2, ... labels.
    colors, labels = np.unique(annotated_label, return_inverse=True)

    n_labels = 2
    
    #Setting up the CRF model
    d = dcrf.DenseCRF2D(original_image.shape[1], original_image.shape[0], n_labels)

    # get unary potentials (neg log probability)
    U = unary_from_labels(labels, n_labels, gt_prob=0.7, zero_unsure=False)
    d.setUnaryEnergy(U)

    # This adds the color-independent term, features are the locations only.
    d.addPairwiseGaussian(sxy=(3, 3), compat=3, kernel=dcrf.DIAG_KERNEL,
                      normalization=dcrf.NORMALIZE_SYMMETRIC)
        
    #Run Inference for 10 steps 
    Q = d.inference(10)

    # Find out the most probable class for each pixel.
    MAP = np.argmax(Q, axis=0)

    return MAP.reshape((original_image.shape[0],original_image.shape[1]))

# %%
test_path='/home/alexanderliao/data/Kaggle/competitions/tgs-salt-identification-challenge/test/images''

# %%
"""
visualizing the effect of applying CRF

"""
nImgs = 3
i = np.random.randint(1000)
j = 1
plt.figure(figsize=(15,15))
plt.subplots_adjust(wspace=0.2,hspace=0.1)  #adjust this to change vertical and horiz. spacings..
while True:
    if str(df.loc[i,'rle_mask'])!=str(np.nan):        
        decoded_mask = rle_decode(df.loc[i,'rle_mask'])        
        orig_img = imread(test_path+df.loc[i,'id']+'.png')
        #Applying CRF on FCN-16 annotated image
        crf_output = crf(orig_img,decoded_mask)
        plt.subplot(nImgs,4,4*j-3)
        plt.imshow(orig_img)
        plt.title('Original image')
        plt.subplot(nImgs,4,4*j-2)
        plt.imshow(decoded_mask) 
        plt.title('Original Mask')
        plt.subplot(nImgs,4,4*j-1)
        plt.imshow(crf_output) 
        plt.title('Mask after CRF')
        if j == nImgs:
            break
        else:
            j = j + 1
    i = i + 1

# %%
"""
used for converting the decoded image to rle mask

"""
def rle_encode(im):
    '''
    im: numpy array, 1 - mask, 0 - background
    Returns run length as string formated
    '''
    pixels = im.flatten()
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

# %%
"""
Applying CRF on the predicted mask 

"""
for i in tqdm(range(df.shape[0])):
    if str(df.loc[i,'rle_mask'])!=str(np.nan):        
        decoded_mask = rle_decode(df.loc[i,'rle_mask'])        
        orig_img = imread(test_path+df.loc[i,'id']+'.png')        
        crf_output = crf(orig_img,decoded_mask)
        df.loc[i,'rle_mask'] = rle_encode(crf_output)

# %%
df.to_csv('crf_correction.csv',index=False)
